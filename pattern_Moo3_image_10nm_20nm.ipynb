# %% [markdown]
# <a href="https://colab.research.google.com/github/yifanlu-bot/twisted-bilayer-MoS2-angle-detection/blob/main/pattern_Moo3_image_10nm_20nm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open the image file
try:
    img = Image.open('/content/20nm 10 min 100x-1.png')
except FileNotFoundError:
    print("Error: Image file not found.")
    exit()

# Split the image into R, G, and B channels
r_channel, g_channel, b_channel = img.split()

# Display each channel as a grayscale image
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(r_channel, cmap='gray')
plt.title('Red Channel')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(g_channel, cmap='gray')
plt.title('Green Channel')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(b_channel, cmap='gray')
plt.title('Blue Channel')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open the image file
try:
    img = Image.open('/content/10nm 10 min 100x-1.png')
except FileNotFoundError:
    print("Error: Image file not found.")
    exit()

# Split the image into R, G, and B channels
r_channel, g_channel, b_channel = img.split()

# Display each channel as a grayscale image
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(r_channel, cmap='gray')
plt.title('Red Channel (10nm 10 min)')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(g_channel, cmap='gray')
plt.title('Green Channel (10nm 10 min)')
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(b_channel, cmap='gray')
plt.title('Blue Channel (10nm 10 min)')
plt.axis('off')

plt.tight_layout()
plt.show()
